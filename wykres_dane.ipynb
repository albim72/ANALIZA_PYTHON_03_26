# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = 'dane.csv'
data = pd.read_csv(file_path)

# %%
data.head(10)
# Out:
#          Data  Wartosc
# 0  2023-01-01       75
# 1  2023-01-02      133
# 2  2023-01-03      141
# 3  2023-01-04      143
# 4  2023-01-05      159
# 5  2023-01-06      201
# 6  2023-01-07      169
# 7  2023-01-08      221
# 8  2023-01-09      206
# 9  2023-01-10      214

# %%
data['Data'] = pd.to_datetime(data['Data'])

# %%
#twrozenie wykresu liniowego
plt.figure(figsize=(10,6))
plt.plot(data['Data'], data['Wartosc'], linestyle='-')

plt.title("Wykres liniowy wartoci w czasie",fontsize=16)
plt.xlabel("Data",fontsize=12)
plt.ylabel("Wartość",fontsize=12)
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3946/3785669462.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
