# %%
def info():
    print("to jest funkcja do wyświetlania komuniakatu")

info()
# Out:
# to jest funkcja do wyświetlania komuniakatu

# %%
print(info())
# Out:
# to jest funkcja do wyświetlania komuniakatu
# None

# %%
def msg():
    return "to jest tekst zwracany"

# %%
print(msg())
# Out:
# to jest tekst zwracany

# %%
def wiadomosc(wd):
    return f"nowa wiadomość: {wd}"

print(wiadomosc("słowa abc"))
# Out:
# nowa wiadomość: słowa abc

# %%
def policz(a,b,c,n):
    return (a+b)*(n-c)

print(policz(4,7,3,6))
# Out:
# 33

# %%
#funkcja rekurencyjna
def factorial(n):
    if n==0 or n==1:
        return 1
    return n*factorial(n-1)

print(factorial(5))
# Out:
# 120

# %%
#funkcja prztwarzająca listę
def filter_even(numbers:list) -> list:
    return [num for num in numbers if num%2==0] #list comprehansion

# %%
liczby = [53,5,3,57,2,4,53,68,97,53,22,35,67,32,58,90,121,146,99]
print(filter_even(liczby))
# Out:
# [2, 4, 68, 22, 32, 58, 90, 146]

# %%
def show_info(*args,**kwargs):
    print(f"Lista argumwntów: {args}")
    print(f"Słownik agumentów: {kwargs}")

# %%
show_info(1,5,3,6,name="logo",numers=45)
# Out:
# Lista argumwntów: (1, 5, 3, 6)
# Słownik agumentów: {'name': 'logo', 'numers': 45}

# %%
#funkcja do tworzenia zamówień
def create_order(client_name,*dishes,**extras):
    print(f"zamówienie dla klienta: {client_name}")

    if dishes:
        print("Zamówienie dnia:")
        for dish in dishes:
            print(f" - {dish}")
    else:
        print("brak zamówionych dań")


    if extras:
        print("\nDodatkowe opcje:")
        for key,value in extras.items():
            print(f" - {key.replace('_',' ').capitalize()}: {value}")
    else:
        print("\nBrak dodatkowych opcji")
    print("\nZamówienie zostało przyjęte....")

# %%
create_order("Anna","Pizza  Margerita","Lasagne",napoj = "Cola",ss="czosnkowy")
print("_"*50)
create_order("Tomek",sos="pikantny",uwagi="bez glutenu")
print("_"*50)
create_order("Marta","Burger","Frytki","Sałatka")
# Out:
# zamówienie dla klienta: Anna
# Zamówienie dnia:
#  - Pizza  Margerita
#  - Lasagne
#
# Dodatkowe opcje:
#  - Napoj: Cola
#  - Ss: czosnkowy
#
# Zamówienie zostało przyjęte....
# __________________________________________________
# zamówienie dla klienta: Tomek
# brak zamówionych dań
#
# Dodatkowe opcje:
#  - Sos: pikantny
#  - Uwagi: bez glutenu
#
# Zamówienie zostało przyjęte....
# __________________________________________________
# zamówienie dla klienta: Marta
# Zamówienie dnia:
#  - Burger
#  - Frytki
#  - Sałatka
#
# Brak dodatkowych opcji
#
# Zamówienie zostało przyjęte....
